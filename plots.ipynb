# %% [markdown]
# ## Generate Plots for CMSC472 Slides/Paper/Poster

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Loss Plots

# %%
df_baselineloss = pd.read_csv(os.path.join('training_output', 'loss', 'baseline.csv')).drop('Wall time', axis=1).rename({'Value': 'Loss'}, axis = 1)
df_baselineloss['model'] = 'baseline'
df_config1loss = pd.read_csv(os.path.join('training_output', 'loss', 'config1.csv')).drop('Wall time', axis=1).rename({'Value': 'Loss'}, axis = 1)
df_config1loss['model'] = '1-Bit'

df_loss = pd.concat([df_baselineloss, df_config1loss])
df_loss
# Out:
#       Step      Loss     model
# 0        5  2.297939  baseline
# 1       19  2.104217  baseline
# 2       41  1.306065  baseline
# 3       48  0.980639  baseline
# 4       63  0.611677  baseline
# ..     ...       ...       ...
# 995   9980  1.809039     1-Bit
# 996   9983  1.798911     1-Bit
# 997   9988  1.834103     1-Bit
# 998   9994  1.843535     1-Bit
# 999  10000  1.769440     1-Bit
#
# [2000 rows x 3 columns]

# %%
sns.set_theme()
sns.lineplot(df_loss, x = 'Step', y = 'Loss', hue = 'model')
plt.title('Training Loss', weight='bold')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
# TODO: training loss plot of 1-bit vs 1.58-bit for 50,000 steps (config2 vs. config3)
df_config2loss = pd.read_csv(os.path.join('training_output', 'loss', 'config2.csv')).drop('Wall time', axis=1).rename({'Value': 'Loss'}, axis = 1)
df_config2loss['model'] = '1-Bit'
df_config2loss.head()
# Out:
#    Step      Loss  model
# 0   108  2.295277  1-Bit
# 1   173  2.262832  1-Bit
# 2   245  2.248022  1-Bit
# 3   260  2.257309  1-Bit
# 4   403  2.061732  1-Bit

# %%
df_config3loss = pd.read_csv(os.path.join('training_output', 'loss', 'config3.csv')).drop('Wall time', axis=1).rename({'Value': 'Loss'}, axis = 1)
df_config3loss['model'] = '1.58-Bit'
df_config3loss.head()
# Out:
#    Step      Loss     model
# 0   108  2.224775  1.58-Bit
# 1   173  2.184726  1.58-Bit
# 2   245  2.019615  1.58-Bit
# 3   260  1.967426  1.58-Bit
# 4   403  1.851943  1.58-Bit

# %%
df_loss = pd.concat([df_baselineloss, df_config2loss, df_config3loss])
df_loss
# Out:
#       Step      Loss     model
# 0        5  2.297939  baseline
# 1       19  2.104217  baseline
# 2       41  1.306065  baseline
# 3       48  0.980639  baseline
# 4       63  0.611677  baseline
# ..     ...       ...       ...
# 995  49865  0.189133  1.58-Bit
# 996  49962  0.171834  1.58-Bit
# 997  49976  0.161936  1.58-Bit
# 998  49990  0.345524  1.58-Bit
# 999  50000  0.213095  1.58-Bit
#
# [3000 rows x 3 columns]

# %%
sns.set_theme()
ax = sns.lineplot(df_loss, x = 'Step', y = 'Loss', hue = 'model')
sns.move_legend(ax, "center right")
plt.title('Training Loss', weight='bold')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %% [markdown]
# #### Validation Accuracy Plots

# %%
df_baselineacc = pd.read_csv(os.path.join('training_output', 'accuracy', 'baseline.csv')).drop('Wall time', axis=1).rename({'Value': 'Accuracy'}, axis = 1)
df_baselineacc['model'] = 'baseline'

df_config1acc = pd.read_csv(os.path.join('training_output', 'accuracy', 'config1.csv')).drop('Wall time', axis=1).rename({'Value': 'Accuracy'}, axis = 1)
df_config1acc['model'] = '1-Bit'

df_acc = pd.concat([df_baselineacc, df_config1acc])
df_acc.head()
# Out:
#    Step  Accuracy     model
# 0   500    0.9816  baseline
# 1  1000    0.9851  baseline
# 2  1500    0.9865  baseline
# 3  2000    0.9886  baseline
# 4  2500    0.9863  baseline

# %%
sns.set_theme()
sns.lineplot(df_acc, x = 'Step', y = 'Accuracy', hue = 'model')
plt.title('Validation Accuracy', weight='bold')
# Out:
# Text(0.5, 1.0, 'Validation Accuracy')

# %%
# 1-bit 50,000 iter run
df_config2acc = pd.read_csv(os.path.join('training_output', 'accuracy', 'config2.csv')).drop('Wall time', axis=1).rename({'Value': 'Accuracy'}, axis = 1)
df_config2acc['model'] = '1-Bit'
df_config2acc.head()
# Out:
#    Step  Accuracy  model
# 0   500    0.2082  1-Bit
# 1  1000    0.2638  1-Bit
# 2  1500    0.2691  1-Bit
# 3  2000    0.2885  1-Bit
# 4  2500    0.2966  1-Bit

# %%
# 1.58-bit 50,000 iter run
df_config3acc = pd.read_csv(os.path.join('training_output', 'accuracy', 'config3.csv')).drop('Wall time', axis=1).rename({'Value': 'Accuracy'}, axis = 1)
df_config3acc['model'] = '1.58-Bit'
df_config3acc.head()
# Out:
#     Step  Accuracy     model
# 0   5000    0.8458  1.58-Bit
# 1  10000    0.9198  1.58-Bit
# 2  15000    0.9376  1.58-Bit
# 3  20000    0.9418  1.58-Bit
# 4  25000    0.9500  1.58-Bit

# %%
df_acc = pd.concat([df_baselineacc, df_config2acc, df_config3acc])
df_acc
# Out:
#      Step  Accuracy     model
# 0     500    0.9816  baseline
# 1    1000    0.9851  baseline
# 2    1500    0.9865  baseline
# 3    2000    0.9886  baseline
# 4    2500    0.9863  baseline
# ..    ...       ...       ...
# 5   30000    0.9530  1.58-Bit
# 6   35000    0.9560  1.58-Bit
# 7   40000    0.9586  1.58-Bit
# 8   45000    0.9579  1.58-Bit
# 9   50000    0.9587  1.58-Bit
#
# [130 rows x 3 columns]

# %%
sns.set_theme()
sns.lineplot(df_acc, x = 'Step', y = 'Accuracy', hue = 'model')
plt.title('Validation Accuracy', weight='bold')
# Out:
# Text(0.5, 1.0, 'Validation Accuracy')
